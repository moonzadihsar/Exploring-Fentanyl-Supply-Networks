# %%
jensen_fentanyl_nodes_1 = ['NPP', 'Aniline', 'Lithium Aluminium Hydride', 'P-toluenesulfonic Acid']
jensen_fentanyl_nodes_2 = ['Propionic Anhydride', '1-benzyl-4-anilinopiperidine','Toluene']
jensen_fentanyl_nodes_3 = ['Palladium on Carbon', 'Hydrogen','Ethanol', '1-benzyl-4-N-propionyl-anlinopiperidine']
jensen_fentanyl_nodes_4 = ['Phenylethylchloride','Sodium Carbonate','Potassium Iodide','4-methyl-2-pentanone', 'Norfentanyl']
jensen_fentanyl_nodes_5=['Fentanyl']
jensen=jensen_fentanyl_nodes_1+jensen_fentanyl_nodes_2+jensen_fentanyl_nodes_3+jensen_fentanyl_nodes_4+jensen_fentanyl_nodes_5

zee_fentanyl_nodes_1=['Pyridine','Thionyl Chloride','Ethanol','Methanol']
zee_fentanyl_nodes_2=['Pirydilpyridinium Chloride','Aniline Hydrochloride','Sodium Hydroxide','Ethanol']
zee_fentanyl_nodes_3=['Propionic Anhydride','4-anilinopyridine','Sodium Hydroxide','Ethanol']
zee_fentanyl_nodes_4=['Ethanol','Phenethyl Bromide','Toluene','N-(4-pyridil)-propionanilide']
zee_fentanyl_nodes_5=['Sodium Hydroxide','Chloroform','Sodium sulphate','Methanol','Platinum Oxide','Hydrogen','Acetic Acid','Ethanol','1-phenylethyl-4-propionanilinopyridinium Bromide']
zee_fentanyl_nodes_6=['Toluene','Propionic Anhydride','Sodium Hydroxide','Sodium sulphate','Methanol', 'N-hexane','1-Phenylethyl-4-anilinopiperidine']
zee_fentanyl_nodes_7=['Fentanyl']
zee=zee_fentanyl_nodes_1+zee_fentanyl_nodes_2+zee_fentanyl_nodes_3+zee_fentanyl_nodes_4+zee_fentanyl_nodes_5+zee_fentanyl_nodes_6

jonczyk_fentanyl_nodes_1= ['Phenethylamine', 'Methyl Acrylate']
jonczyk_fentanyl_nodes_2= ['Sodium Methoxide', 'Hydrogen', 'N,N-bis(2-methoxycarbonylethyl)phenethylamine']
jonczyk_fentanyl_nodes_3= ['Aniline', 'Toluene', 'NPP', 'P-toluenesulfonic Acid', 'Lithium Aluminium Hydride','Sodium Borohydride']
jonczyk_fentanyl_nodes_4= ['ANPP', 'Propionyl Chloride','Benzene']
jonczyk_fentanyl_nodes_5= ['Fentanyl Hydrochloride']
jonczyk=jonczyk_fentanyl_nodes_1+jonczyk_fentanyl_nodes_2+jonczyk_fentanyl_nodes_3+jonczyk_fentanyl_nodes_4+jonczyk_fentanyl_nodes_5

vlm_fentanyl_nodes_1=["Sodium Chloride", "Sodium Bicarbonate", "Sodium sulphate", "Cesium Carbonate", "Phenethyl Bromide", "4-piperidone Hydrochloride", "Acetonitrile", "Ethyl Acetate", "Dichloromethane"]
vlm_fentanyl_nodes_2=["Acetic Acid", "Sodium Triacetoxyborohydride", "Aniline", "Dichloromethane", "Sodium Bicarbonate", "Sodium Chloride", "Sodium sulphate", "Ethyl Acetate", "NPP"]
vlm_fentanyl_nodes_3=["DIPEA","Propionyl Chloride","Sodium Chloride","Sodium Bicarbonate","Sodium sulphate","Ethyl Acetate","Dichloromethane","ANPP"]
vlm_fentanyl_nodes_4=['Fentanyl']
vlm=vlm_fentanyl_nodes_1+vlm_fentanyl_nodes_2+vlm_fentanyl_nodes_3+vlm_fentanyl_nodes_4

sigfried_fentanyl_nodes_1=['4-piperidone Hydrochloride','Acetonitrile','Potassium Carbonate','TBAB','TEBA','Polyethylene Glycol','Phenethyl Bromide','Phenethyl Tosylate','Sodium sulphate']
sigfried_fentanyl_nodes_2=['NPP','Aniline','Molecular Sieve']
sigfried_fentanyl_nodes_3=['NPP N Phenyl-imine','Tetrahydrofuran','Methanol','Sodium Borohydride','Hydrochloric Acid','Sodium Chloride']
sigfried_fentanyl_nodes_4=['ANPP Hydrochloride','Sodium Hydroxide','Dichloromethane']
sigfried_fentanyl_nodes_5=['ANPP','Pyridine','Propionyl Chloride','Hydrochloric Acid','Dichloromethane','Sodium Chloride','Acetone']
sigfried_fentanyl_nodes_6=['Fentanyl Hydrochloride']
sigfried=sigfried_fentanyl_nodes_1+sigfried_fentanyl_nodes_2+sigfried_fentanyl_nodes_3+sigfried_fentanyl_nodes_4+sigfried_fentanyl_nodes_5+sigfried_fentanyl_nodes_6

gupta_fentanyl_nodes_1=['Nitrogen','Phenylacetaldehyde','4-piperidone Hydrochloride','Dichloroethane','Triethyl Amine','Sodium Triacetoxyborohydride']
gupta_fentanyl_nodes_2=['NPP','Aniline','Sodium Triacetoxyborohydride','Acetic Acid']
gupta_fentanyl_nodes_3=['ANPP','Propionyl Chloride','Dichloromethane','Sodium Hydroxide','Hydrochloric Acid','Sodium sulphate','Acetone','Sodium Hydroxide','Petroleum Ether']
gupta_fentanyl_nodes_4=['Fentanyl Hydrochloride']
gupta=gupta_fentanyl_nodes_1+gupta_fentanyl_nodes_2+gupta_fentanyl_nodes_3+gupta_fentanyl_nodes_4

# %% [markdown]
# How many ingredients are there in total?

# %%
total_nodes=list(set(jensen+zee+jonczyk+vlm+sigfried+gupta))
print(len(total_nodes))

with open("chemicals.txt", "w") as f:
    for item in total_nodes:
        f.write("%s\n" % item)
# Out:
# 67

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Your data
jaccard = {}
nodes = [jensen, zee, vlm, jonczyk, sigfried, gupta]
labels = ["jensen", "zee", "vlm", "optim", "sigfried", "gupta"]

for index, node in enumerate(nodes):
    for index2, node2 in enumerate(nodes):
        if index != index2:
            intersection = len(set(node).intersection(set(node2)))
            union = len(set(node).union(set(node2)))
            jaccard[index, index2] = intersection / union if union > 0 else 0
        else:
            jaccard[index, index2] = 1  # Jaccard with itself = 1

# Convert to matrix
size = len(nodes)
matrix = np.zeros((size, size))
for (i, j), value in jaccard.items():
    matrix[i][j] = value

# Plot heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(matrix, annot=True, xticklabels=labels, yticklabels=labels, cmap="viridis", fmt=".2f")
plt.title("Jaccard Similarity Heatmap")
plt.show()

# %%
appearance={}
for ind_list in [jensen,zee,jonczyk,vlm,sigfried,gupta]:
    for node in set(ind_list):
        appearance[node]=appearance.get(node, 0)+1
print(len(appearance))
import heapq
top5 = heapq.nlargest(28
, appearance.items(), key=lambda x: x[1])
print(top5)
print(max(appearance, key=appearance.get))
# Out:
# 68
# [('NPP', 5), ('Aniline', 5), ('Sodium Sulfate', 4), ('ANPP', 4), ('Propionyl Chloride', 4), ('Toluene', 3), ('Hydrogen', 3), ('Sodium Hydroxide', 3), ('Acetic Acid', 3), ('Phenethyl Bromide', 3), ('Fentanyl Hydrochloride', 3), ('4-piperidone Hydrochloride', 3), ('Dichloromethane', 3), ('Ethanol', 2), ('Lithium Aluminium Hydride', 2), ('P-toluenesulfonic Acid', 2), ('Fentanyl', 2), ('Propionic Anhydride', 2), ('Methanol', 2), ('Pyridine', 2), ('Sodium Borohydride', 2), ('Acetonitrile', 2), ('Sodium Chloride', 2), ('Sodium Triacetoxyborohydride', 2), ('Acetone', 2), ('Hydrochloric Acid', 2), ('Norfentanyl', 1), ('1-benzyl-4-N-propionyl-anlinopiperidine', 1)]
# NPP

# %%
from itertools import combinations
ingredient_sets = [set(ind_list) for ind_list in [jensen, zee, jonczyk, vlm, sigfried, gupta]]
print(len(ingredient_sets))
max_k = max(len(set.intersection(*grp)) for grp in combinations(ingredient_sets, 3))
# Out:
# 6

# %%
from itertools import combinations

def mine_frequent_itemsets(transactions, min_support):
    n = len(transactions)
    itemsets = []
    items = sorted(set.union(*transactions))  # all unique ingredients
    transactions = list(map(set, transactions))

    # loop for k = 1 ... up to size of largest transaction
    k = 1
    current_sets = [{i} for i in items]

    while current_sets:
        freq_sets = []
        for s in current_sets:
            support = sum(1 for t in transactions if s.issubset(t))
            if support >= min_support:
                freq_sets.append((frozenset(s), support))
                itemsets.append((frozenset(s), support))

        # generate candidates for next level
        next_sets = set()
        for a, b in combinations(freq_sets, 2):
            union = a[0] | b[0]
            if len(union) == k+1:
                next_sets.add(union)
        current_sets = list(next_sets)
        k += 1

    return itemsets

frequent_itemsets = mine_frequent_itemsets(ingredient_sets, min_support=3)
for s, sup in frequent_itemsets:
    print(s, sup)
# Out:
# frozenset({'4-piperidone Hydrochloride'}) 3
# frozenset({'ANPP'}) 4
# frozenset({'Acetic Acid'}) 3
# frozenset({'Aniline'}) 5
# frozenset({'Dichloromethane'}) 3
# frozenset({'Fentanyl Hydrochloride'}) 3
# frozenset({'Hydrogen'}) 3
# frozenset({'NPP'}) 5
# frozenset({'Phenethyl Bromide'}) 3
# frozenset({'Propionyl Chloride'}) 4
# frozenset({'Sodium Hydroxide'}) 3
# frozenset({'Sodium Sulfate'}) 4
# frozenset({'Toluene'}) 3
# frozenset({'Hydrogen', 'Toluene'}) 3
# frozenset({'Phenethyl Bromide', 'Sodium Sulfate'}) 3
# frozenset({'ANPP', 'Sodium Sulfate'}) 3
# frozenset({'NPP', '4-piperidone Hydrochloride'}) 3
# frozenset({'Aniline', 'Dichloromethane'}) 3
# frozenset({'Aniline', 'NPP'}) 5
# frozenset({'4-piperidone Hydrochloride', 'Propionyl Chloride'}) 3
# frozenset({'Fentanyl Hydrochloride', 'NPP'}) 3
# frozenset({'Propionyl Chloride', 'Dichloromethane'}) 3
# frozenset({'Sodium Hydroxide', 'Sodium Sulfate'}) 3
# frozenset({'Acetic Acid', 'Sodium Sulfate'}) 3
# frozenset({'4-piperidone Hydrochloride', 'Dichloromethane'}) 3
# frozenset({'Aniline', '4-piperidone Hydrochloride'}) 3
# frozenset({'Propionyl Chloride', 'ANPP'}) 4
# frozenset({'Aniline', 'Propionyl Chloride'}) 4
# frozenset({'Fentanyl Hydrochloride', 'Propionyl Chloride'}) 3
# frozenset({'NPP', 'ANPP'}) 4
# frozenset({'NPP', 'Propionyl Chloride'}) 4
# frozenset({'NPP', 'Sodium Sulfate'}) 3
# frozenset({'NPP', 'Dichloromethane'}) 3
# frozenset({'4-piperidone Hydrochloride', 'Sodium Sulfate'}) 3
# frozenset({'Propionyl Chloride', 'Sodium Sulfate'}) 3
# frozenset({'4-piperidone Hydrochloride', 'ANPP'}) 3
# frozenset({'Aniline', 'Sodium Sulfate'}) 3
# frozenset({'Aniline', 'ANPP'}) 4
# frozenset({'Aniline', 'Fentanyl Hydrochloride'}) 3
# frozenset({'Dichloromethane', 'Sodium Sulfate'}) 3
# frozenset({'Dichloromethane', 'ANPP'}) 3
# frozenset({'Fentanyl Hydrochloride', 'ANPP'}) 3
# frozenset({'Aniline', 'NPP', 'Sodium Sulfate'}) 3
# frozenset({'4-piperidone Hydrochloride', 'Propionyl Chloride', 'ANPP'}) 3
# frozenset({'Aniline', '4-piperidone Hydrochloride', 'Dichloromethane'}) 3
# frozenset({'4-piperidone Hydrochloride', 'Dichloromethane', 'Sodium Sulfate'}) 3
# frozenset({'Aniline', 'Dichloromethane', 'ANPP'}) 3
# frozenset({'Dichloromethane', 'ANPP', 'Sodium Sulfate'}) 3
# frozenset({'NPP', 'Dichloromethane', 'ANPP'}) 3
# frozenset({'Aniline', 'NPP', 'Dichloromethane'}) 3
# frozenset({'Aniline', 'Propionyl Chloride', 'Sodium Sulfate'}) 3
# frozenset({'NPP', '4-piperidone Hydrochloride', 'ANPP'}) 3
# frozenset({'NPP', '4-piperidone Hydrochloride', 'Propionyl Chloride'}) 3
# frozenset({'NPP', 'Propionyl Chloride', 'Dichloromethane'}) 3
# frozenset({'Fentanyl Hydrochloride', 'Propionyl Chloride', 'ANPP'}) 3
# frozenset({'NPP', '4-piperidone Hydrochloride', 'Dichloromethane'}) 3
# frozenset({'Propionyl Chloride', 'ANPP', 'Sodium Sulfate'}) 3
# frozenset({'Aniline', 'Propionyl Chloride', 'ANPP'}) 4
# frozenset({'4-piperidone Hydrochloride', 'ANPP', 'Sodium Sulfate'}) 3
# frozenset({'Aniline', '4-piperidone Hydrochloride', 'ANPP'}) 3
# frozenset({'4-piperidone Hydrochloride', 'Dichloromethane', 'ANPP'}) 3
# frozenset({'Aniline', 'ANPP', 'Fentanyl Hydrochloride'}) 3
# frozenset({'Fentanyl Hydrochloride', 'NPP', 'ANPP'}) 3
# frozenset({'Aniline', 'Propionyl Chloride', 'Dichloromethane'}) 3
# frozenset({'Propionyl Chloride', 'Dichloromethane', 'Sodium Sulfate'}) 3
# frozenset({'Propionyl Chloride', 'Dichloromethane', 'ANPP'}) 3
# frozenset({'NPP', 'ANPP', 'Sodium Sulfate'}) 3
# frozenset({'Aniline', 'NPP', 'ANPP'}) 4
# frozenset({'NPP', '4-piperidone Hydrochloride', 'Sodium Sulfate'}) 3
# frozenset({'Aniline', 'NPP', '4-piperidone Hydrochloride'}) 3
# frozenset({'Aniline', '4-piperidone Hydrochloride', 'Sodium Sulfate'}) 3
# frozenset({'NPP', 'Propionyl Chloride', 'ANPP'}) 4
# frozenset({'Aniline', 'NPP', 'Propionyl Chloride'}) 4
# frozenset({'NPP', 'Propionyl Chloride', 'Sodium Sulfate'}) 3
# frozenset({'Aniline', 'Dichloromethane', 'Sodium Sulfate'}) 3
# frozenset({'Fentanyl Hydrochloride', 'NPP', 'Propionyl Chloride'}) 3
# frozenset({'Aniline', 'NPP', 'Fentanyl Hydrochloride'}) 3
# frozenset({'4-piperidone Hydrochloride', 'Propionyl Chloride', 'Sodium Sulfate'}) 3
# frozenset({'Aniline', '4-piperidone Hydrochloride', 'Propionyl Chloride'}) 3
# frozenset({'Aniline', 'ANPP', 'Sodium Sulfate'}) 3
# frozenset({'Aniline', 'Propionyl Chloride', 'Fentanyl Hydrochloride'}) 3
# frozenset({'4-piperidone Hydrochloride', 'Propionyl Chloride', 'Dichloromethane'}) 3
# frozenset({'NPP', 'Dichloromethane', 'Sodium Sulfate'}) 3
# frozenset({'4-piperidone Hydrochloride', 'ANPP', 'NPP', 'Sodium Sulfate'}) 3
# frozenset({'4-piperidone Hydrochloride', 'ANPP', 'Aniline', 'NPP'}) 3
# frozenset({'4-piperidone Hydrochloride', 'Aniline', 'NPP', 'Sodium Sulfate'}) 3
# frozenset({'Propionyl Chloride', 'Dichloromethane', 'Aniline', 'Sodium Sulfate'}) 3
# frozenset({'4-piperidone Hydrochloride', 'Propionyl Chloride', 'Dichloromethane', 'ANPP'}) 3
# frozenset({'4-piperidone Hydrochloride', 'Dichloromethane', 'Aniline', 'Sodium Sulfate'}) 3
# frozenset({'4-piperidone Hydrochloride', 'Dichloromethane', 'ANPP', 'Aniline'}) 3
# frozenset({'4-piperidone Hydrochloride', 'Dichloromethane', 'ANPP', 'Sodium Sulfate'}) 3
# frozenset({'4-piperidone Hydrochloride', 'Propionyl Chloride', 'NPP', 'Sodium Sulfate'}) 3
# frozenset({'4-piperidone Hydrochloride', 'Propionyl Chloride', 'Aniline', 'NPP'}) 3
# frozenset({'4-piperidone Hydrochloride', 'Propionyl Chloride', 'Aniline', 'Sodium Sulfate'}) 3
# frozenset({'Propionyl Chloride', 'ANPP', 'Aniline', 'Sodium Sulfate'}) 3
# frozenset({'Dichloromethane', 'ANPP', 'Aniline', 'NPP'}) 3
# frozenset({'Dichloromethane', 'ANPP', 'NPP', 'Sodium Sulfate'}) 3
# frozenset({'Propionyl Chloride', 'Dichloromethane', 'Aniline', 'NPP'}) 3
# frozenset({'Propionyl Chloride', 'Dichloromethane', 'NPP', 'Sodium Sulfate'}) 3
# frozenset({'ANPP', 'Aniline', 'NPP', 'Sodium Sulfate'}) 3
# frozenset({'4-piperidone Hydrochloride', 'Propionyl Chloride', 'Dichloromethane', 'Aniline'}) 3
# frozenset({'4-piperidone Hydrochloride', 'Propionyl Chloride', 'Dichloromethane', 'Sodium Sulfate'}) 3
# frozenset({'Dichloromethane', 'Aniline', 'NPP', 'Sodium Sulfate'}) 3
# frozenset({'Fentanyl Hydrochloride', 'Propionyl Chloride', 'ANPP', 'Aniline'}) 3
# frozenset({'Fentanyl Hydrochloride', 'Propionyl Chloride', 'ANPP', 'NPP'}) 3
# frozenset({'4-piperidone Hydrochloride', 'Propionyl Chloride', 'ANPP', 'NPP'}) 3
# frozenset({'Propionyl Chloride', 'Aniline', 'NPP', 'Sodium Sulfate'}) 3
# frozenset({'Fentanyl Hydrochloride', 'ANPP', 'Aniline', 'NPP'}) 3
# frozenset({'4-piperidone Hydrochloride', 'Dichloromethane', 'ANPP', 'NPP'}) 3
# frozenset({'Propionyl Chloride', 'Dichloromethane', 'ANPP', 'Aniline'}) 3
# frozenset({'Propionyl Chloride', 'Dichloromethane', 'ANPP', 'Sodium Sulfate'}) 3
# frozenset({'Propionyl Chloride', 'Dichloromethane', 'ANPP', 'NPP'}) 3
# frozenset({'Fentanyl Hydrochloride', 'Propionyl Chloride', 'Aniline', 'NPP'}) 3
# frozenset({'4-piperidone Hydrochloride', 'Propionyl Chloride', 'Dichloromethane', 'NPP'}) 3
# frozenset({'Dichloromethane', 'ANPP', 'Aniline', 'Sodium Sulfate'}) 3
# frozenset({'4-piperidone Hydrochloride', 'ANPP', 'Aniline', 'Sodium Sulfate'}) 3
# frozenset({'4-piperidone Hydrochloride', 'Propionyl Chloride', 'ANPP', 'Sodium Sulfate'}) 3
# frozenset({'4-piperidone Hydrochloride', 'Propionyl Chloride', 'ANPP', 'Aniline'}) 3
# frozenset({'4-piperidone Hydrochloride', 'Dichloromethane', 'Aniline', 'NPP'}) 3
# frozenset({'4-piperidone Hydrochloride', 'Dichloromethane', 'NPP', 'Sodium Sulfate'}) 3
# frozenset({'Propionyl Chloride', 'ANPP', 'NPP', 'Sodium Sulfate'}) 3
# frozenset({'Propionyl Chloride', 'ANPP', 'Aniline', 'NPP'}) 4
# frozenset({'ANPP', 'NPP', 'Propionyl Chloride', 'Dichloromethane', 'Aniline'}) 3
# frozenset({'4-piperidone Hydrochloride', 'NPP', 'Sodium Sulfate', 'Propionyl Chloride', 'Dichloromethane'}) 3
# frozenset({'4-piperidone Hydrochloride', 'ANPP', 'NPP', 'Dichloromethane', 'Aniline'}) 3
# frozenset({'4-piperidone Hydrochloride', 'NPP', 'Sodium Sulfate', 'Dichloromethane', 'Aniline'}) 3
# frozenset({'4-piperidone Hydrochloride', 'ANPP', 'Sodium Sulfate', 'Propionyl Chloride', 'Aniline'}) 3
# frozenset({'4-piperidone Hydrochloride', 'ANPP', 'NPP', 'Propionyl Chloride', 'Aniline'}) 3
# frozenset({'Fentanyl Hydrochloride', 'ANPP', 'NPP', 'Propionyl Chloride', 'Aniline'}) 3
# frozenset({'4-piperidone Hydrochloride', 'NPP', 'Propionyl Chloride', 'Dichloromethane', 'Aniline'}) 3
# frozenset({'4-piperidone Hydrochloride', 'Sodium Sulfate', 'Propionyl Chloride', 'Dichloromethane', 'Aniline'}) 3
# frozenset({'ANPP', 'Sodium Sulfate', 'Propionyl Chloride', 'Dichloromethane', 'Aniline'}) 3
# frozenset({'4-piperidone Hydrochloride', 'ANPP', 'NPP', 'Sodium Sulfate', 'Propionyl Chloride'}) 3
# frozenset({'4-piperidone Hydrochloride', 'ANPP', 'NPP', 'Propionyl Chloride', 'Dichloromethane'}) 3
# frozenset({'ANPP', 'NPP', 'Sodium Sulfate', 'Dichloromethane', 'Aniline'}) 3
# frozenset({'NPP', 'Sodium Sulfate', 'Propionyl Chloride', 'Dichloromethane', 'Aniline'}) 3
# frozenset({'4-piperidone Hydrochloride', 'ANPP', 'Sodium Sulfate', 'Propionyl Chloride', 'Dichloromethane'}) 3
# frozenset({'4-piperidone Hydrochloride', 'ANPP', 'NPP', 'Sodium Sulfate', 'Aniline'}) 3
# frozenset({'ANPP', 'NPP', 'Sodium Sulfate', 'Propionyl Chloride', 'Aniline'}) 3
# frozenset({'4-piperidone Hydrochloride', 'NPP', 'Sodium Sulfate', 'Propionyl Chloride', 'Aniline'}) 3
# frozenset({'ANPP', 'NPP', 'Sodium Sulfate', 'Propionyl Chloride', 'Dichloromethane'}) 3
# frozenset({'4-piperidone Hydrochloride', 'ANPP', 'Sodium Sulfate', 'Dichloromethane', 'Aniline'}) 3
# frozenset({'4-piperidone Hydrochloride', 'ANPP', 'NPP', 'Sodium Sulfate', 'Dichloromethane'}) 3
# frozenset({'4-piperidone Hydrochloride', 'ANPP', 'Propionyl Chloride', 'Dichloromethane', 'Aniline'}) 3
# frozenset({'4-piperidone Hydrochloride', 'ANPP', 'NPP', 'Propionyl Chloride', 'Dichloromethane', 'Aniline'}) 3
# frozenset({'4-piperidone Hydrochloride', 'NPP', 'Sodium Sulfate', 'Propionyl Chloride', 'Dichloromethane', 'Aniline'}) 3
# frozenset({'4-piperidone Hydrochloride', 'ANPP', 'Sodium Sulfate', 'Propionyl Chloride', 'Dichloromethane', 'Aniline'}) 3
# frozenset({'4-piperidone Hydrochloride', 'ANPP', 'NPP', 'Sodium Sulfate', 'Propionyl Chloride', 'Dichloromethane'}) 3
# frozenset({'4-piperidone Hydrochloride', 'ANPP', 'NPP', 'Sodium Sulfate', 'Propionyl Chloride', 'Aniline'}) 3
# frozenset({'ANPP', 'NPP', 'Sodium Sulfate', 'Propionyl Chloride', 'Dichloromethane', 'Aniline'}) 3
# frozenset({'4-piperidone Hydrochloride', 'ANPP', 'NPP', 'Sodium Sulfate', 'Dichloromethane', 'Aniline'}) 3
# frozenset({'4-piperidone Hydrochloride', 'ANPP', 'NPP', 'Sodium Sulfate', 'Propionyl Chloride', 'Dichloromethane', 'Aniline'}) 3

# %%
def get_closed_and_maximal(itemsets):
    closed = []
    maximal = []
    for s, sup in itemsets:
        # Find supersets of s
        supersets = [(ss, ss_sup) for ss, ss_sup in itemsets if s < ss]
        # Closed check
        if not any(ss_sup == sup for ss, ss_sup in supersets):
            closed.append((s, sup))
        # Maximal check
        if not supersets:
            maximal.append((s, sup))
    return closed, maximal

closed_sets, maximal_sets = get_closed_and_maximal(frequent_itemsets)

print("\nClosed sets:")
for s, sup in closed_sets:
    print(s, sup)

print("\nMaximal sets:")
for s, sup in maximal_sets:
    print(s, sup)
# Out:
# Closed sets:
# frozenset({'Sodium Sulfate'}) 4
# frozenset({'Hydrogen', 'Toluene'}) 3
# frozenset({'Phenethyl Bromide', 'Sodium Sulfate'}) 3
# frozenset({'Aniline', 'NPP'}) 5
# frozenset({'Sodium Hydroxide', 'Sodium Sulfate'}) 3
# frozenset({'Acetic Acid', 'Sodium Sulfate'}) 3
# frozenset({'Propionyl Chloride', 'ANPP', 'Aniline', 'NPP'}) 4
# frozenset({'Fentanyl Hydrochloride', 'ANPP', 'NPP', 'Propionyl Chloride', 'Aniline'}) 3
# frozenset({'4-piperidone Hydrochloride', 'ANPP', 'NPP', 'Sodium Sulfate', 'Propionyl Chloride', 'Dichloromethane', 'Aniline'}) 3
#
# Maximal sets:
# frozenset({'Hydrogen', 'Toluene'}) 3
# frozenset({'Phenethyl Bromide', 'Sodium Sulfate'}) 3
# frozenset({'Sodium Hydroxide', 'Sodium Sulfate'}) 3
# frozenset({'Acetic Acid', 'Sodium Sulfate'}) 3
# frozenset({'Fentanyl Hydrochloride', 'ANPP', 'NPP', 'Propionyl Chloride', 'Aniline'}) 3
# frozenset({'4-piperidone Hydrochloride', 'ANPP', 'NPP', 'Sodium Sulfate', 'Propionyl Chloride', 'Dichloromethane', 'Aniline'}) 3

# %%
import itertools
from collections import Counter

pair_appearance = Counter()
pair_lift={}
for ind_list in [jensen, zee, jonczyk, vlm, sigfried, gupta]:
    for node_pair in itertools.combinations(set(ind_list), 2):
        pair_appearance[frozenset(node_pair)]+=1 
for ind_list in [jensen, zee, jonczyk, vlm, sigfried, gupta]:
    for node_pair in itertools.combinations(set(ind_list), 2):
        pair_lift[frozenset(node_pair)]=(pair_appearance[frozenset(node_pair)]*6)/((appearance[node_pair[0]]*appearance[node_pair[1]]))
import heapq
top5 = heapq.nlargest(5, pair_appearance.items(), key=lambda x: x[1])
print(top5)
for i in top5:
    print(i,pair_lift[i[0]])
# Out:
# [(frozenset({'Aniline', 'NPP'}), 5), (frozenset({'NPP', 'ANPP'}), 4), (frozenset({'Propionyl Chloride', 'ANPP'}), 4), (frozenset({'Aniline', 'ANPP'}), 4), (frozenset({'NPP', 'Propionyl Chloride'}), 4)]
# (frozenset({'Aniline', 'NPP'}), 5) 1.2
# (frozenset({'NPP', 'ANPP'}), 4) 1.2
# (frozenset({'Propionyl Chloride', 'ANPP'}), 4) 1.5
# (frozenset({'Aniline', 'ANPP'}), 4) 1.2
# (frozenset({'NPP', 'Propionyl Chloride'}), 4) 1.2
